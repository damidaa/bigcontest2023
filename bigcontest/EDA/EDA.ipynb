# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/Admin/bigcontest/data/bigcontest.csv")
data
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 0        50.0      F                골드                무료                그린
# 1         NaN    NaN               NaN               NaN               NaN
# 2         NaN    NaN               NaN               NaN               NaN
# 3         NaN    NaN               NaN               NaN               NaN
# 4        50.0      M                무료               NaN               NaN
# ...       ...    ...               ...               ...               ...
# 1920863   NaN    NaN               NaN               NaN               NaN
# 1920864  20.0      F                무료              싹틔우미               NaN
# 1920865  50.0      F                블루                무료                그린
# 1920866   NaN    NaN               NaN               NaN               NaN
# 1920867   NaN    NaN               NaN               NaN               NaN
#
# ...

# %% [markdown]
# ----------------------------------------------

# %%
data['discount_type'].unique()
# Out:
# array(['일반', '초대권', '블루회원 할인20%', '골드회원 할인20%', '기획사',
#        'K-lang 멤버십 회원(1인2매)20%', '기획사판매', '골드회원 할인30%', 'R석 기획사 할인',
#        '싹틔우미 할인40%', '라흐마니노프탄생150주년(8매/3.27까지)20%', '공연진행석', '골드회원 할인10%',
#        '장애인/국가유공자 할인50%', '싹딜가(골드)50%', '당일할인티켓', '그린회원 할인5%',
#        '초,중,고,대학생(본인만)30%', '조기예매 할인40%', '그린회원 할인20%', '한화초대석',
#        '단체100인이상50%', '공연예매권', '초/중/고등학생 할인(본인만)30%', '골드회원 할인15%',
#        '골드회원 할인25%', '우리카드 우수회원', '조기예매 할인(1인8매/3월11일까지)30%', '신세계석',
#        '골드회원 할인5%', '정기회원', '만65세 이상(본인만)50%', '싹딜가(블루)50%', '그린회원 할인15%',
#        '직장인 할인(1인2매)20%', '블루회원 할인10%', '기획사판매20%',
#        '초/중/고/대학생 할인(본인만)50%', '문화릴레이(1인2매/공연유료티켓제시)10%', '조기예매 할인10%',
#        '노블회원 할인40%', 'K-Lang 할인(1인2매)20%', '골드회원 할인40%',
#        '초/중/고등학생 할인(본인만)20%', '조기예매 할인(1인2매/~10월31일까지)30%', '기업석',
#        '초/중/고/대학생 할인30%', '초/중/고/대학생 할인50%', '의사상자(동반1인/신분증지참)50%',
#        '초,중,고,대학생(본인만)50%', '조기예매할인(1인8매/~6.30까지)30%', '그린회원 할인10%',
# ...

# %%
data[ ['membership_type_1','membership_type_2','membership_type_3','membership_type_4','membership_type_5','price','discount_type'] ]
# Out:
#         membership_type_1 membership_type_2 membership_type_3  \
# 0                      골드                무료                그린
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                      무료               NaN               NaN
# ...                   ...               ...               ...
# 1920863               NaN               NaN               NaN
# 1920864                무료              싹틔우미               NaN
# 1920865                블루                무료                그린
# 1920866               NaN               NaN               NaN
# 1920867               NaN               NaN               NaN
#
#         membership_type_4 membership_type_5   price         discount_type
# 0                     NaN               NaN   10000                    일반
# ...

# %%
mt_1_g = data[ data['membership_type_1']=='골드' ]
mt_1_g['price']
# Out:
# 0           10000
# 8           56000
# 15         120000
# 18          42000
# 33          10000
#             ...
# 1920793     14000
# 1920804     90000
# 1920836     35000
# 1920843     10000
# 1920860     15000
# Name: price, Length: 163487, dtype: int64

# %%
dt_invite = data[ data['discount_type']=='초대권']
dt_invite[ ['membership_type_1','membership_type_2','membership_type_3','membership_type_4','membership_type_5']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 899280 entries, 1 to 1920867
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   membership_type_1  2 non-null      object
#  1   membership_type_2  2 non-null      object
#  2   membership_type_3  2 non-null      object
#  3   membership_type_4  0 non-null      object
#  4   membership_type_5  0 non-null      object
# dtypes: object(5)
# memory usage: 41.2+ MB

# %%
dt_invite1 = dt_invite['membership_type_1'].fillna(0)

dt_invite[ dt_invite['membership_type_1'] != 0 ]
# Out:
#          age gender membership_type_1 membership_type_2 membership_type_3  \
# 1        NaN    NaN               NaN               NaN               NaN
# 2        NaN    NaN               NaN               NaN               NaN
# 3        NaN    NaN               NaN               NaN               NaN
# 6        NaN    NaN               NaN               NaN               NaN
# 7        NaN    NaN               NaN               NaN               NaN
# ...      ...    ...               ...               ...               ...
# 1920857  NaN    NaN               NaN               NaN               NaN
# 1920859  NaN    NaN               NaN               NaN               NaN
# 1920863  NaN    NaN               NaN               NaN               NaN
# 1920866  NaN    NaN               NaN               NaN               NaN
# 1920867  NaN    NaN               NaN               NaN               NaN
#
#         membership_type_4 membership_type_5  membership_type_6  tran_date  \
# ...

# %% [markdown]
# --------------------------------
#
# TEST

# %%
data['seat']
# Out:
# 0            3층 BOX9 10
# 1               1층 7열 5
# 2          1층 C블록 16열 3
# 3               1층 2열 3
# 4           1층 B블록12열 7
#                ...
# 1920863    1층 A블록 14열 6
# 1920864      3층 B블록5열 4
# 1920865         1층 7열 3
# 1920866     1층 B블록 9열 5
# 1920867     1층 B블록 3열 4
# Name: seat, Length: 1920868, dtype: object

# %% [markdown]
# -------------------

# %%
data[ ['membership_type_1','membership_type_2','membership_type_3','membership_type_4','membership_type_5','price'] ]
# Out:
#         membership_type_1 membership_type_2 membership_type_3  \
# 0                      골드                무료                그린
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                      무료               NaN               NaN
# ...                   ...               ...               ...
# 1920863               NaN               NaN               NaN
# 1920864                무료              싹틔우미               NaN
# 1920865                블루                무료                그린
# 1920866               NaN               NaN               NaN
# 1920867               NaN               NaN               NaN
#
#         membership_type_4 membership_type_5   price
# 0                     NaN               NaN   10000
# 1                     NaN               NaN       0
# 2                     NaN               NaN       0
# ...

# %%
data['membership_type_5'].unique()
# Out:
# array([nan, '그린'], dtype=object)

# %% [markdown]
# ----------------

# %%
membership_type_5_green = data[ data['membership_type_5']=='그린' ]
membership_type_5_green
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 844      20.0      M                블루                골드                무료
# 2211     30.0      F                블루                골드                무료
# 2901     30.0      F                블루                골드                무료
# 3520     20.0      F                블루                골드                무료
# 4496     20.0      M                블루                골드                무료
# ...       ...    ...               ...               ...               ...
# 1915119  30.0      F                블루                골드                무료
# 1917294  30.0      F                블루                골드                무료
# 1917432  30.0      M                블루                골드                무료
# 1918530  30.0      F                블루                골드                무료
# 1920335  30.0      M                블루                골드                무료
#
# ...

# %%
(membership_type_5_green['membership_type_4']=='노블').sum()
# Out:
# 111

# %%
(membership_type_5_green['membership_type_4']=='싹틔우미').sum()
# Out:
# 1171

# %% [markdown]
# ----------------------------------------------

# %%
membership_type_5_green['price']
# Out:
# 844         42000
# 2211        42000
# 2901       171000
# 3520       114000
# 4496        21000
#             ...
# 1915119     18000
# 1917294    171000
# 1917432      7000
# 1918530     30000
# 1920335    135000
# Name: price, Length: 1282, dtype: int64

# %%
membership_type_5_green.isna().sum()
# Out:
# age                     0
# gender                  0
# membership_type_1       0
# membership_type_2       0
# membership_type_3       0
# membership_type_4       0
# membership_type_5       0
# membership_type_6    1282
# tran_date               0
# tran_time               0
# play_date               0
# play_st_time            0
# seat                    0
# price                   0
# ticket_cancel           0
# discount_type           0
# performance_code        0
# pre_open_date         371
# open_date               0
# genre                  10
# place                   0
# running_time            0
# intermission            0
# member_yn               0
# dtype: int64

# %% [markdown]
# --------

# %%
membership_type_5_non_green = data[ data['membership_type_5']!='그린' ]
membership_type_5_non_green
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 0        50.0      F                골드                무료                그린
# 1         NaN    NaN               NaN               NaN               NaN
# 2         NaN    NaN               NaN               NaN               NaN
# 3         NaN    NaN               NaN               NaN               NaN
# 4        50.0      M                무료               NaN               NaN
# ...       ...    ...               ...               ...               ...
# 1920863   NaN    NaN               NaN               NaN               NaN
# 1920864  20.0      F                무료              싹틔우미               NaN
# 1920865  50.0      F                블루                무료                그린
# 1920866   NaN    NaN               NaN               NaN               NaN
# 1920867   NaN    NaN               NaN               NaN               NaN
#
# ...

# %%
(membership_type_5_non_green['membership_type_4']=='싹틔우미').sum()
# Out:
# 2525

# %%
(membership_type_5_non_green['membership_type_4']=='노블').sum()
# Out:
# 2984

# %% [markdown]
# -----------

# %%
membership_type_5_non_green['price']
# Out:
# 0           10000
# 1               0
# 2               0
# 3               0
# 4          180000
#             ...
# 1920863         0
# 1920864     21000
# 1920865     24000
# 1920866         0
# 1920867         0
# Name: price, Length: 1919586, dtype: int64

# %%
print ( data['membership_type_1'].unique() )
print ( data['membership_type_2'].unique() )
print ( data['membership_type_3'].unique() )
print ( data['membership_type_4'].unique() )
print ( data['membership_type_5'].unique() )
# Out:
# ['골드' nan '무료' '블루']
# ['무료' nan '그린' '싹틔우미' '골드' '노블']
# ['그린' nan '무료' '싹틔우미' '노블']
# [nan '그린' '싹틔우미' '노블']
# [nan '그린']
